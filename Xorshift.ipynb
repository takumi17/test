# %%
def xor32():
    global y
    y = y ^ (y << 13)
    y = y ^ (y >> 17)
    y = y ^ (y << 5)
    return y

def xor64():
    global x
    x = x ^ (x << 13)
    x = x ^ (x >> 7)
    x = x ^ (x << 17)
    return x

def xor96():
    global x96, y96, z96
    t = (x96 ^ (x96 << 3)) ^ (y96 ^ (y96 >> 19)) ^ (z96 ^ (z96 << 6))
    x96 = y96
    y96 = z96
    return z96 ^ (z96 << 16) ^ t

def xor128():
    global x128, y128, z128, w128
    t = x128 ^ (x128 << 11)
    x128 = y128
    y128 = z128
    z128 = w128
    w128 = (w128 ^ (w128 >> 19)) ^ (t ^ (t >> 8))
    return w128

# 初期値設定
y = 2463534242
x = 88172645463325252
x96 = 123456789
y96 = 362436069
z96 = 521288629
x128 = 123456789
y128 = 362436069
z128 = 521288629
w128 = 88675123

# テスト
print("xor32:", xor32())
print("xor64:", xor64())
print("xor96:", xor96())
print("xor128:", xor128())
# Out:
# xor32: 660888219700579
# xor64: 95272899234400648529057200
# xor96: 34178664243115
# xor128: 252977563114

# %% [markdown]
# # ChatGPTによる解説
# このコードは, Xorshiftアルゴリズムを使用して擬似乱数を生成する関数 `xor32`, `xor64`, `xor96`, `xor128` を定義しています. それぞれの関数は異なるビット数の乱数を生成します.
#
# - `xor32`: 32ビットの乱数を生成する関数です. Xorshiftアルゴリズムに従い, グローバル変数 `y` をビットシフトして XOR 演算を行います. Xorshiftアルゴリズムの一連の操作を適用した後, `y` の値を返します.
# 具体的には, 以下の手順で疑似乱数を生成します.
# 1. グローバル変数 `y` を利用しています. これは前回の状態を保持するための変数です.
# 2. `y` の値に対してビット演算を行います.
#    - `y` を左に13ビットシフトして, それと `y` 自身との排他的論理和を計算します.
# 3. 次に, 右に17ビットシフトして, それと `y` 自身との排他的論理和を計算します.
# 4. 最後に, 再び左に5ビットシフトして, それと `y` 自身との排他的論理和を計算します.
# 5. 最終的に, 更新された `y` の値を返します.
# この手順によって、`xor32` 関数は呼び出されるたびに新しい乱数を生成します。
#
# - `xor64`: 64ビットの乱数を生成する関数です. 同様に, グローバル変数 `x` を使用してXorshiftアルゴリズムを実装します.
# 具体的には、次の手順で疑似乱数を生成します：
# 1. グローバル変数 `x` を利用しています. これは前回の状態を保持するための変数です.
# 2. `x` を `(x << 13)` だけ左にビットシフトし, その結果と `x` 自体との排他的論理和をとります. これにより, ビットを左に13ビットシフトしたものと元の値との間で XOR 操作が行われます.
# 3. `x` を `(x >> 7)` だけ右にビットシフトし, その結果と `x` 自体との排他的論理和をとります. これにより, ビットを右に7ビットシフトしたものと元の値との間で XOR 操作が行われます.
# 4. `x` を再度 `(x << 17)` だけ左にビットシフトし, その結果と `x` 自体との排他的論理和をとります. これにより, ビットを左に17ビットシフトしたものと元の値との間で XOR 操作が行われます.
# 5. 更新された `x` の値を返します.
# この手順によって, `xor64` 関数は呼び出されるたびに新しい64ビットの疑似乱数を生成します.
#
#
# - `xor96`: 96ビットの乱数を生成する関数です. グローバル変数 `x96`, `y96`, `z96` を使用してXorshiftアルゴリズムを実装します.
# 具体的には、次の手順で疑似乱数を生成します.
# 1. グローバル変数 `x96`, `y96`, `z96` を利用しています. これらは前回の状態を保持するための変数です.
# 2. `(x96 ^ (x96 << 3)) ^ (y96 ^ (y96 >> 19)) ^ (z96 ^ (z96 << 6))` を計算しています. これはXorshiftアルゴリズムの基本的な手順に基づいており, `x96`,`y96`, `z96` のビットの特定のビット位置をシフトし, それらとの排他的論理和をとっています.
# 3. 更新された `x96`, `y96`, `z96` の値を計算しています.
#    - `x96` には `y96` の値が代入され, `y96` には `z96` の値が代入されます.
# 4. 最終的に, `z96` と `(z96 << 16)`, および `t` の排他的論理和を計算して返します.
# この手順によって, `xor96` 関数は呼び出されるたびに新しい96ビットの疑似乱数を生成します.
#
# - `xor128`: 128ビットの乱数を生成する関数です. グローバル変数 `x128`, `y128`, `z128`, `w128` を使用してXorshiftアルゴリズムを実装します.
# 具体的には、次の手順で疑似乱数を生成します：
# 1. グローバル変数 `x128`, `y128`, `z128`, `w128` を利用しています. これらは前回の状態を保持するための変数です.
# 2. `x128` を `(x128 << 11)` だけ左にビットシフトし, その結果と `x128` 自体との排他的論理和をとります. これにより、ビットを左に11ビットシフトしたものと元の値との間で XOR 操作が行われます. これを変数 `t` に格納します.
# 3. 変数 `t` を `w128` と `w128` を右に19ビットシフトした値との間で XOR 操作を行い, さらに `(t ^ (t >> 8))` を計算します. これらの結果を `w128` に格納します.
# 4. 変数 `x128` の値を `y128` に、`y128` の値を `z128` に、`z128` の値を `w128` に更新します.
# 5. 更新された `w128` の値を返します.
#
# この手順によって, `xor128` 関数は呼び出されるたびに新しい128ビットの疑似乱数を生成します.
#
#
# それぞれの関数は, Xorshiftアルゴリズムに基づいて状態を更新し, 最終的な乱数値を返します. これらの関数は, 呼び出されるたびに異なる乱数を生成しますが, それぞれの関数は異なるビット数の乱数を生成することに注意してください.
#
# 最後に, 各関数をテストするために, グローバル変数 `y`, `x`, `x96`, `y96`, `z96`, `x128`, `y128`, `z128`, `w128` に初期値が設定されています. 各関数が呼び出された結果が, それぞれのビット数に応じた乱数の値を示します.

# %%
# xor32から1から100までの100個の乱数を生成
xor32_numbers = [xor32() % 100 + 1 for _ in range(100)]

# xor64から1から100までの100個の乱数を生成
xor64_numbers = [xor64() % 100 + 1 for _ in range(100)]

# xor96から1から100までの100個の乱数を生成
xor96_numbers = [xor96() % 100 + 1 for _ in range(100)]

# xor128から1から100までの100個の乱数を生成
xor128_numbers = [xor128() % 100 + 1 for _ in range(100)]

# 結果を出力
print("xor32 numbers:", xor32_numbers)
print("xor64 numbers:", xor64_numbers)
print("xor96 numbers:", xor96_numbers)
print("xor128 numbers:", xor128_numbers)
# Out:
# xor32 numbers: [5, 33, 36, 53, 33, 15, 32, 89, 26, 67, 86, 12, 9, 6, 49, 40, 63, 60, 3, 83, 48, 32, 54, 40, 40, 28, 51, 38, 54, 81, 51, 43, 98, 53, 22, 50, 2, 37, 65, 57, 88, 62, 87, 26, 83, 46, 56, 91, 48, 90, 71, 52, 77, 4, 80, 19, 55, 51, 77, 70, 8, 37, 49, 82, 37, 94, 68, 25, 1, 3, 70, 50, 91, 55, 73, 29, 80, 25, 36, 78, 96, 43, 76, 17, 60, 7, 87, 5, 61, 26, 70, 95, 10, 56, 62, 55, 70, 51, 18, 23]
# xor64 numbers: [40, 77, 2, 47, 66, 58, 36, 21, 62, 80, 29, 72, 12, 59, 15, 7, 45, 50, 71, 28, 56, 68, 22, 45, 86, 45, 37, 15, 78, 16, 11, 14, 100, 26, 2, 66, 35, 94, 36, 28, 39, 42, 2, 68, 60, 86, 19, 22, 41, 56, 93, 14, 19, 19, 82, 73, 84, 42, 46, 90, 19, 37, 25, 99, 98, 76, 18, 85, 11, 34, 39, 28, 20, 84, 27, 67, 19, 99, 27, 93, 83, 82, 77, 26, 5, 40, 31, 42, 98, 87, 76, 63, 87, 7, 71, 27, 88, 25, 82, 47]
# ...

# %% [markdown]
# # ChatGPTによる解説
# このコードは, `xor32`, `xor64`, `xor96`, `xor128` の各関数から1から100までの範囲の100個の乱数を生成し, それぞれのビット数に応じてリストに保存しています.
#
# - `xor32_numbers`: `xor32` 関数を使って1から100までの範囲の乱数を生成し, それぞれをリストに保存しています. 生成された乱数は100個で, それぞれ1から100までの整数です.
#
# - `xor64_numbers`: 同様に `xor64` 関数を使って1から100までの範囲の乱数を生成し, リストに保存します.
#
# - `xor96_numbers`: `xor96` 関数を使って1から100までの範囲の乱数を生成し, リストに保存します.
#
# - `xor128_numbers`: `xor128` 関数を使って1から100までの範囲の乱数を生成し, リストに保存します.
#
# 各乱数の生成には, 対応する Xorshift 関数を使用し, それぞれの結果をリストに保存しています. 最後に, 生成された乱数リストを出力しています. これにより, それぞれのビット数に応じた乱数列が得られます.
#
#
# ```python
# [xor32() % 100 + 1 for _ in range(100)]
# ```
#
# これは、次の手順で解釈されます：
#
# 1. `range(100)` は, 0から99までの整数を要素とするリストを生成します.
# 2. `_` は、ダミーの変数で, この変数はループ内で使われないことを示しています.
# 3. リスト内包表記の各要素に対して,`xor32()` 関数を呼び出して乱数を生成します.
# 4. 生成された乱数に `% 100` を適用して, 0から99までの範囲の乱数を生成します.
# 5. さらに `+ 1` を適用して, 1から100までの範囲の乱数に変換します.
# 6. これらの乱数を要素とするリストが生成されます.
#
# 結果的に、`xor32()` 関数を使って100回乱数を生成し, その結果をリストに格納しています.
#
#
# `%（モジュロ演算子）`は, 剰余を計算する演算子です. a % b は, a を b で割った際の余りを返します. この場合, xor32() 関数から返される値を100で割った余りを計算しています.
